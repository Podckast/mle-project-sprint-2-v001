# %%
import pandas as pd

# %%
df = pd.read_csv('/home/mle-user/mle_projects/mle-project-sprint-2-v001/mlflow_server/initial_data.csv')

# %%
df.head()
# Out:
#    id  build_year  building_type_int   latitude  longitude  ceiling_height
# 0   1        1965                  6  55.717113  37.781120            2.64  \
# 1   2        2001                  2  55.794849  37.608013            3.00
# 2   3        2000                  4  55.740040  37.761742            2.70
# 3   4        2002                  4  55.672016  37.570877            2.64
# 4   5        1971                  1  55.808807  37.707306            2.60
#
#    flats_count  floors_total  has_elevator  floor  kitchen_area  living_area
# 0           84            12          True      9           9.9    19.900000  \
# 1           97            10          True      7           0.0    16.600000
# 2           80            10          True      9           9.0    32.000000
# 3          771            17          True      1          10.1    43.099998
# 4          208             9          True      3           3.0    14.000000
#
# ...
